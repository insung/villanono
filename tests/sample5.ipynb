# %%
import os
import pandas as pd

from util import read_original_file



df = read_original_file("csv\\매매\\2023_연립다세대(매매).csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23087 entries, 0 to 23086
# Data columns (total 20 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   NO        23087 non-null  int64
#  1   시군구       23087 non-null  object
#  2   번지        23087 non-null  object
#  3   본번        23087 non-null  int64
#  4   부번        23087 non-null  int64
#  5   건물명       23086 non-null  object
#  6   전용면적(㎡)   23087 non-null  float64
#  7   대지권면적(㎡)  23087 non-null  float64
#  8   계약년월      23087 non-null  int64
#  9   계약일       23087 non-null  int64
#  10  거래금액(만원)  23087 non-null  object
#  11  층         23087 non-null  int64
#  12  매수자       23087 non-null  object
#  13  매도자       23087 non-null  object
#  14  건축년도      23087 non-null  int64
#  15  도로명       23087 non-null  object
#  16  해제사유발생일   23087 non-null  object
#  17  거래유형      23087 non-null  object
#  18  중개사소재지    23087 non-null  object
#  19  등기일자      23087 non-null  object
# ...

# %%
df2 = df.copy()

df2.columns = [
    "NO",
    "시군구",
    "번지",
    "본번",
    "부번",
    "건물명",
    "전용면적",
    "대지권면적",
    "계약년월",
    "계약일",
    "거래금액(만원)",
    "층",
    "매수자",
    "매도자",
    "건축년도",
    "도로명",
    "해제사유발생일",
    "거래유형",
    "중개사소재지",
    "등기일자"
]

# %%
groupbyDF = df2.query("시군구 == '서울특별시 서대문구 북가좌동'").groupby("계약년월", as_index=False)

# %%
groupbyDF.describe().to_csv("test2.csv")

# %%
rent2023 = read_original_file("csv\\전월세\\2023_연립다세대(전월세).csv")
# Out:
# c:\Github\villanono\util.py:17: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pandas.read_csv(temp_outputfile_path, skiprows=skiprows)

# %%
rent2023.columns
# Out:
# Index(['NO', '시군구', '번지', '본번', '부번', '건물명', '전월세구분', '전용면적(㎡)', '계약년월', '계약일',
#        '보증금(만원)', '월세금(만원)', '층', '건축년도', '도로명', '계약기간', '계약구분', '갱신요구권 사용',
#        '종전계약 보증금(만원)', '종전계약 월세(만원)', '주택유형'],
#       dtype='object')

# %%
groupRent2023 = rent2023.query("시군구 == '서울특별시 서대문구 북가좌동' & 전월세구분 == '전세'").groupby("계약년월", as_index=False)

# %%
groupRent2023.describe()
# Out:
#       계약년월    NO                                                             \
#            count           mean          std       min        25%       50%
# 0   202301  30.0  131995.066667  2879.780594  127500.0  129393.25  132054.5
# 1   202302  50.0  120901.220000  3712.367424  114853.0  117624.25  120875.5
# 2   202303  36.0  107742.055556  3440.795339  102832.0  105664.75  107374.5
# 3   202304  36.0   95883.527778  3429.059625   90577.0   93611.50   95267.5
# 4   202305  36.0   84299.916667  3276.902077   79026.0   81288.75   84473.5
# 5   202306  29.0   73218.448276  2846.133249   68000.0   71228.00   73563.0
# 6   202307  39.0   61526.205128  3673.863406   56041.0   58259.50   61969.0
# 7   202308  51.0   50348.156863  3417.982038   45105.0   46708.50   50121.0
# 8   202309  55.0   38665.254545  2903.065074   34006.0   36858.00   38048.0
# 9   202310  45.0   27211.755556  3219.961590   22318.0   24252.00   27972.0
# ...

# %%
geo_code = read_original_file("국토교통부 국토지리정보원_구지형도_시군구코드_20231107.csv")

# %%
geo_code.head()
# Out:
#    41  41287      고양시일산서구
# 0  41  41285      고양시일산동구
# 1  41  41820  가평군
# 2  42  42730  횡성군
# 3  42  42790  화천군
# 4  42  42720  홍천군
